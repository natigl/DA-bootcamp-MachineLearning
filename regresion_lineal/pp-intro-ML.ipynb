# %% [markdown]
# ### Machine Learning / Regresión Lineal - Pair Programming

# %% [markdown]
# Empezamos una nueva lección, y este es el momento de poner en práctica los conocimientos adquiridos sobre la Regresión Lineal Simple I. Para ello os vamos a pedir que por vuestra cuenta busqueis un dataset que os guste, por ejemplo de Kaggle o de donde queráis extraerlo. De forma que vamos a probar a realizar ajustes lineales con el fin de predecir alguna de sus variables. Este dataset será el que iremos usando a lo largo de todas las sesiones de pairprogramming de regresión lineal.
#
#
# Se ruega a la hora de realizar la entrega que incluyais el conjunto de datos que hayais decidido emplear para estos ejercicios.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,8)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Los objetivos de hoy son:
#
#
# 1. Buscar un conjunto de datos a analizar:
# Es necesario que el conjunto de datos a analizar tenga variables numéricas y categóricas, primando que haya más de una variable de tipo numérico. Ya que tambien se utilizarán serán útiles a la hora de realizar predicciones en las clases de regresión lineal múltiple. Así mismo se recomienda que los datasets esten ligeramente limpios para facilitar los análisis.
# 2. Explicar los datos y las variables disponibles en el conjunto de datos seleccionado:
#     - Esto se hace para que comprendais mejor los datos con los que estais trabajando.
#     - Realizar un EDA sencillo para la variable dependiente y la variable independiente.

# %%
df = pd.read_csv("data/adult.data.csv", index_col = 0)
df.head(2)
# Out:
#             State-gov   77516   Bachelors   13        Never-married  \
# 39
# 50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 38            Private  215646     HS-grad    9             Divorced
#
#           Adm-clerical   Not-in-family   White   Male   2174   0   40  \
# 39
# 50     Exec-managerial         Husband   White   Male      0   0   13
# 38   Handlers-cleaners   Not-in-family   White   Male      0   0   40
#
#      United-States   <=50K
# 39
# 50   United-States   <=50K
# 38   United-States   <=50K

# %%
nuevo_nombre = {col: col.strip().replace(" ", "").lower() for col in df.columns}

# %%
df.rename(columns = nuevo_nombre, inplace = True)

# %%
renombre = {'white': 'ethnicity',
            '2174' : 'capital_gain',
            'male' : 'gender',
            '0' : 'capital_lost',
            '13' : 'education_num',
            '40' : 'hours_week',
            '77516' : 'final_weight',
            'not-in-family' : 'relationship',
            'never-married' : 'marital_status',
            'adm-clerical' : 'ocupation',
            'united-states' : 'country',
            '<=50k' : 'salary'
        
            }

# %%
df.rename(columns = renombre, inplace = True)

# %%
df.shape
# Out:
# (32560, 14)

# %%
df["capital_gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: capital_gain, Length: 119, dtype: int64

# %%
df.shape
# Out:
# (32560, 14)

# %%
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# final_weight   32560.0  189781.814373  105549.764924  12285.0  117831.5
# education_num  32560.0      10.080590       2.572709      1.0       9.0
# capital_gain   32560.0    1077.615172    7385.402999      0.0       0.0
# capital_lost   32560.0      87.306511     402.966116      0.0       0.0
# hours_week     32560.0      40.437469      12.347618      1.0      40.0
#
#                     50%       75%        max
# final_weight   178363.0  237054.5  1484705.0
# education_num      10.0      12.0       16.0
# capital_gain        0.0       0.0    99999.0
# capital_lost        0.0       0.0     4356.0
# hours_week         40.0      45.0       99.0

# %%
df.describe(include='object')
# Out:
#        state-gov bachelors       marital_status        ocupation relationship  \
# count      32560     32560                32560            32560        32560
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#        ethnicity gender         country  salary
# count      32560  32560           32560   32560
# unique         5      2              42       2
# top        White   Male   United-States   <=50K
# freq       27815  21789           29169   24719

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32560 entries, 50 to 52
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state-gov       32560 non-null  object
#  1   final_weight    32560 non-null  int64
#  2   bachelors       32560 non-null  object
#  3   education_num   32560 non-null  int64
#  4   marital_status  32560 non-null  object
#  5   ocupation       32560 non-null  object
#  6   relationship    32560 non-null  object
#  7   ethnicity       32560 non-null  object
#  8   gender          32560 non-null  object
#  9   capital_gain    32560 non-null  int64
#  10  capital_lost    32560 non-null  int64
#  11  hours_week      32560 non-null  int64
#  12  country         32560 non-null  object
#  13  salary          32560 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# state-gov         0
# final_weight      0
# bachelors         0
# education_num     0
# marital_status    0
# ocupation         0
# relationship      0
# ethnicity         0
# gender            0
# capital_gain      0
# capital_lost      0
# hours_week        0
# country           0
# salary            0
# dtype: int64

# %%
numericas = df.select_dtypes(include=['int64', 'float64'])
lista_columnas = list(numericas)

# %%
def detectar_outliers(lista_columnas, dataframe): 
    
    dicc_indices = {}
   
    for col in lista_columnas:
        
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)

        IQR = Q3 - Q1
    
        outlier_step = 1.5 * IQR
        
        outliers_data = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)]
        
        if outliers_data.shape[0] > 0: 
        
            dicc_indices[col] = (list(outliers_data.index)) 
        
    return dicc_indices

# %%
# Índices de los outliers:

indices = detectar_outliers(lista_columnas, df)

# %%
# Columnas con outliers:

indices.keys()
# Out:
# dict_keys(['final_weight', 'education_num', 'capital_gain', 'capital_lost', 'hours_week'])

# %%
indices
# Out:
# {'final_weight': [19,
#   31,
#   18,
#   24,
#   71,
#   27,
#   34,
#   30,
#   41,
#   37,
#   35,
#   43,
#   57,
#   19,
#   29,
#   39,
#   20,
#   41,
#   31,
#   30,
#   47,
#   45,
#   45,
#   24,
#   23,
#   19,
#   59,
#   39,
#   25,
#   23,
#   35,
#   36,
#   50,
#   76,
#   40,
#   28,
#   36,
#   28,
#   34,
#   50,
#   63,
#   29,
#   32,
#   34,
#   20,
#   54,
#   28,
#   46,
#   20,
#   42,
#   69,
#   37,
#   35,
#   45,
#   41,
#   44,
#   32,
#   32,
#   28,
#   19,
#   21,
#   27,
#   42,
#   44,
#   29,
#   31,
#   39,
#   29,
#   39,
#   23,
#   32,
#   25,
#   41,
#   30,
#   23,
#   22,
#   23,
#   18,
#   47,
#   37,
#   34,
#   30,
#   29,
#   27,
#   19,
#   18,
#   34,
#   56,
#   41,
#   32,
#   20,
#   32,
#   22,
#   39,
#   37,
#   25,
#   47,
#   34,
#   24,
#   31,
#   61,
#   28,
#   38,
#   33,
#   28,
#   30,
#   19,
#   31,
#   29,
#   47,
#   35,
#   43,
#   54,
#   35,
#   46,
#   40,
#   23,
#   58,
#   52,
#   22,
#   21,
#   27,
#   22,
#   32,
#   30,
#   19,
#   51,
#   37,
#   24,
#   18,
#   23,
#   53,
#   43,
#   39,
#   64,
#   40,
#   23,
#   19,
#   52,
#   25,
#   29,
#   21,
#   34,
#   27,
#   59,
#   30,
#   21,
#   45,
#   30,
#   35,
#   21,
#   43,
#   53,
#   67,
#   21,
#   27,
#   69,
#   44,
#   34,
#   41,
#   37,
#   34,
#   22,
#   52,
#   32,
#   68,
#   40,
#   63,
#   34,
#   20,
#   19,
#   30,
#   33,
#   35,
#   29,
#   34,
#   18,
#   39,
#   44,
#   36,
#   31,
#   45,
#   49,
#   48,
#   52,
#   31,
#   20,
#   57,
#   29,
#   22,
#   23,
#   22,
#   57,
#   70,
#   56,
#   32,
#   30,
#   47,
#   40,
#   27,
#   25,
#   33,
#   22,
#   59,
#   29,
#   21,
#   20,
#   17,
#   72,
#   34,
#   21,
#   47,
#   24,
#   31,
#   34,
#   18,
#   52,
#   67,
#   32,
#   41,
#   51,
#   47,
#   61,
#   56,
#   23,
#   52,
#   18,
#   39,
#   68,
#   25,
#   41,
#   47,
#   60,
#   27,
#   37,
#   24,
#   34,
#   23,
#   20,
#   23,
#   26,
#   37,
#   46,
#   46,
#   30,
#   31,
#   17,
#   23,
#   26,
#   33,
#   69,
#   18,
#   18,
#   42,
#   44,
#   40,
#   43,
#   46,
#   35,
#   53,
#   39,
#   31,
#   47,
#   35,
#   23,
#   36,
#   46,
#   47,
#   31,
#   28,
#   28,
#   26,
#   25,
#   24,
#   33,
#   26,
#   69,
#   19,
#   19,
#   20,
#   25,
#   56,
#   27,
#   21,
#   25,
#   32,
#   27,
#   38,
#   53,
#   41,
#   23,
#   23,
#   24,
#   52,
#   58,
#   38,
#   26,
#   51,
#   25,
#   19,
#   58,
#   47,
#   31,
#   69,
#   41,
#   32,
#   44,
#   24,
#   61,
#   23,
#   44,
#   36,
#   22,
#   44,
#   24,
#   35,
#   38,
#   64,
#   36,
#   25,
#   27,
#   30,
#   28,
#   59,
#   19,
#   54,
#   35,
#   19,
#   63,
#   20,
#   25,
#   30,
#   23,
#   44,
#   18,
#   42,
#   46,
#   37,
#   34,
#   36,
#   27,
#   24,
#   25,
#   23,
#   22,
#   38,
#   38,
#   55,
#   49,
#   62,
#   58,
#   57,
#   54,
#   43,
#   24,
#   19,
#   41,
#   19,
#   53,
#   28,
#   30,
#   49,
#   33,
#   34,
#   57,
#   41,
#   33,
#   36,
#   25,
#   18,
#   32,
#   43,
#   55,
#   72,
#   22,
#   31,
#   21,
#   30,
#   30,
#   34,
#   72,
#   40,
#   27,
#   44,
#   34,
#   34,
#   39,
#   24,
#   56,
#   59,
#   22,
#   29,
#   22,
#   44,
#   23,
#   24,
#   22,
#   37,
#   24,
#   21,
#   41,
#   23,
#   27,
#   40,
#   34,
#   34,
#   36,
#   37,
#   51,
#   45,
#   20,
#   23,
#   31,
#   22,
#   19,
#   27,
#   23,
#   46,
#   26,
#   46,
#   24,
#   31,
#   39,
#   30,
#   34,
#   18,
#   48,
#   42,
#   65,
#   39,
#   59,
#   33,
#   24,
#   22,
#   45,
#   33,
#   40,
#   31,
#   38,
#   32,
#   43,
#   37,
#   32,
#   51,
#   25,
#   24,
#   43,
#   19,
#   46,
#   23,
#   44,
#   44,
#   55,
#   21,
#   28,
#   20,
#   25,
#   36,
#   62,
#   63,
#   44,
#   32,
#   28,
#   25,
#   27,
#   31,
#   17,
#   19,
#   48,
#   34,
#   31,
#   46,
#   20,
#   61,
#   29,
#   18,
#   25,
#   43,
#   22,
#   29,
#   31,
#   30,
#   38,
#   27,
#   33,
#   43,
#   23,
#   31,
#   23,
#   36,
#   23,
#   33,
#   35,
#   37,
#   19,
#   27,
#   32,
#   18,
#   26,
#   31,
#   23,
#   42,
#   34,
#   39,
#   65,
#   33,
#   21,
#   32,
#   45,
#   41,
#   27,
#   47,
#   23,
#   25,
#   23,
#   37,
#   24,
#   31,
#   24,
#   44,
#   49,
#   23,
#   25,
#   31,
#   19,
#   26,
#   19,
#   38,
#   38,
#   42,
#   51,
#   20,
#   39,
#   23,
#   25,
#   19,
#   24,
#   64,
#   58,
#   22,
#   25,
#   43,
#   36,
#   21,
#   37,
#   36,
#   41,
#   24,
#   36,
#   34,
#   72,
#   36,
#   39,
#   44,
#   36,
#   36,
#   29,
#   59,
#   55,
#   28,
#   38,
#   37,
#   33,
#   57,
#   68,
#   26,
#   24,
#   71,
#   19,
#   36,
#   48,
#   52,
#   21,
#   36,
#   30,
#   44,
#   43,
#   43,
#   41,
#   40,
#   55,
#   56,
#   32,
#   36,
#   25,
#   53,
#   50,
#   21,
#   45,
#   41,
#   33,
#   19,
#   31,
#   22,
#   26,
#   80,
#   33,
#   20,
#   32,
#   34,
#   37,
#   33,
#   30,
#   25,
#   45,
#   26,
#   26,
#   69,
#   49,
#   44,
#   19,
#   58,
#   38,
#   48,
#   29,
#   63,
#   40,
#   58,
#   35,
#   32,
#   34,
#   43,
#   39,
#   30,
#   33,
#   20,
#   25,
#   35,
#   29,
#   21,
#   19,
#   20,
#   42,
#   29,
#   18,
#   32,
#   28,
#   19,
#   35,
#   45,
#   20,
#   22,
#   32,
#   57,
#   25,
#   37,
#   55,
#   44,
#   38,
#   25,
#   33,
#   25,
#   35,
#   22,
#   26,
#   23,
#   31,
#   40,
#   34,
#   35,
#   46,
#   47,
#   28,
#   17,
#   37,
#   44,
#   35,
#   25,
#   34,
#   20,
#   31,
#   19,
#   34,
#   17,
#   43,
#   39,
#   24,
#   39,
#   24,
#   33,
#   34,
#   22,
#   38,
#   52,
#   23,
#   41,
#   40,
#   33,
#   68,
#   25,
#   26,
#   33,
#   33,
#   31,
#   24,
#   20,
#   66,
#   19,
#   41,
#   24,
#   17,
#   26,
#   30,
#   24,
#   38,
#   31,
#   59,
#   41,
#   56,
#   28,
#   48,
#   45,
#   72,
#   32,
#   61,
#   48,
#   33,
#   34,
#   31,
#   29,
#   35,
#   29,
#   27,
#   38,
#   25,
#   19,
#   24,
#   38,
#   54,
#   39,
#   23,
#   23,
#   32,
#   24,
#   27,
#   49,
#   30,
#   59,
#   46,
#   42,
#   20,
#   35,
#   45,
#   23,
#   42,
#   26,
#   45,
#   23,
#   31,
#   48,
#   21,
#   22,
#   33,
#   56,
#   63,
#   41,
#   46,
#   32,
#   24,
#   18,
#   43,
#   28,
#   30,
#   54,
#   33,
#   51,
#   22,
#   24,
#   38,
#   23,
#   53,
#   20,
#   35,
#   46,
#   62,
#   38,
#   27,
#   40,
#   37,
#   47,
#   19,
#   24,
#   23,
#   18,
#   46,
#   33,
#   19,
#   35,
#   20,
#   40,
#   46,
#   43,
#   47,
#   20,
#   54,
#   50,
#   47,
#   22,
#   28,
#   35,
#   24,
#   27,
#   42,
#   29,
#   24,
#   35,
#   25,
#   32,
#   54,
#   26,
#   28,
#   55,
#   24,
#   17,
#   23,
#   28,
#   36,
#   30,
#   42,
#   47,
#   65,
#   20,
#   18,
#   21,
#   55,
#   28,
#   18,
#   47,
#   27,
#   19,
#   20,
#   40,
#   42,
#   58,
#   35,
#   44,
#   18,
#   34,
#   24,
#   22,
#   37,
#   54,
#   23,
#   51,
#   21,
#   50,
#   34,
#   21,
#   31,
#   24,
#   17,
#   29,
#   18,
#   25,
#   36,
#   46,
#   47,
#   23,
#   50,
#   18,
#   31,
#   38,
#   51,
#   29,
#   38,
#   31,
#   40,
#   27,
#   46,
#   20,
#   36,
#   35,
#   32,
#   28,
#   37,
#   21,
#   67,
#   34,
#   33,
#   34,
#   48,
#   19,
#   30,
#   42,
#   39,
#   48,
#   60,
#   48,
#   46,
#   47,
#   36,
#   54,
#   41,
#   43,
#   27,
#   30,
#   25,
#   43,
#   42,
#   39,
#   33,
#   47,
#   21,
#   51,
#   42,
#   35,
#   33,
#   33,
#   38,
#   44,
#   28,
#   38,
#   31,
#   28,
#   54,
#   45,
#   40,
#   42,
#   28,
#   30,
#   22,
#   30,
#   23,
#   25,
#   18,
#   21,
#   21,
#   36,
#   36,
#   24,
#   39,
#   20,
#   23,
#   21,
#   29,
#   23,
#   36,
#   38,
#   33,
#   28,
#   36,
#   42,
#   41,
#   41,
#   43,
#   46,
#   49,
#   56,
#   31,
#   27,
#   49,
#   21,
#   38,
#   50,
#   39,
#   61,
#   24,
#   21,
#   32,
#   30,
#   24,
#   49,
#   26,
#   32,
#   36,
#   36,
#   22,
#   25,
#   41,
#   36,
#   26,
#   56,
#   61,
#   23,
#   32,
#   53,
#   26,
#   39,
#   29,
#   26,
#   40,
#   24,
#   42,
#   19,
#   53,
#   38,
#   28,
#   24,
#   28,
#   50,
#   18,
#   25],
#  'education_num': [34,
#   46,
#   32,
#   31,
#   68,
#   40,
#   23,
#   54,
#   64,
#   53,
#   50,
#   50,
#   22,
#   17,
#   46,
#   28,
#   52,
#   50,
#   63,
#   23,
#   53,
#   57,
#   45,
#   60,
#   60,
#   47,
#   44,
#   66,
#   37,
#   55,
#   63,
#   42,
#   33,
#   51,
#   51,
#   48,
#   76,
#   68,
#   41,
#   63,
#   26,
#   26,
#   62,
#   58,
#   40,
#   69,
#   56,
#   51,
#   27,
#   37,
#   62,
#   51,
#   32,
#   50,
#   66,
#   63,
#   73,
#   25,
#   31,
#   53,
#   65,
#   39,
#   28,
#   24,
#   61,
#   30,
#   47,
#   47,
#   35,
#   60,
#   23,
#   51,
#   33,
#   54,
#   56,
#   63,
#   27,
#   70,
#   35,
#   52,
#   60,
#   61,
#   65,
#   40,
#   57,
#   27,
#   28,
#   50,
#   38,
#   43,
#   23,
#   53,
#   80,
#   61,
#   50,
#   41,
#   44,
#   56,
#   25,
#   31,
#   71,
#   23,
#   31,
#   68,
#   31,
#   55,
#   61,
#   19,
#   51,
#   20,
#   31,
#   82,
#   45,
#   56,
#   36,
#   29,
#   74,
#   36,
#   41,
#   37,
#   33,
#   55,
#   50,
#   31,
#   35,
#   19,
#   39,
#   61,
#   76,
#   26,
#   45,
#   27,
#   24,
#   68,
#   53,
#   30,
#   61,
#   43,
#   56,
#   32,
#   75,
#   28,
#   28,
#   35,
#   52,
#   52,
#   24,
#   66,
#   67,
#   54,
#   64,
#   37,
#   64,
#   68,
#   48,
#   46,
#   56,
#   47,
#   32,
#   57,
#   58,
#   47,
#   21,
#   27,
#   46,
#   23,
#   47,
#   28,
#   52,
#   25,
#   43,
#   38,
#   22,
#   30,
#   33,
#   61,
#   53,
#   44,
#   37,
#   49,
#   42,
#   25,
#   43,
#   57,
#   49,
#   37,
#   29,
#   74,
#   35,
#   49,
#   46,
#   46,
#   49,
#   27,
#   37,
#   50,
#   64,
#   57,
#   41,
#   42,
#   19,
#   72,
#   49,
#   19,
#   49,
#   46,
#   60,
#   61,
#   58,
#   25,
#   51,
#   41,
#   37,
#   59,
#   53,
#   62,
#   33,
#   26,
#   22,
#   45,
#   22,
#   55,
#   63,
#   42,
#   27,
#   80,
#   53,
#   49,
#   31,
#   77,
#   62,
#   26,
#   56,
#   41,
#   47,
#   54,
#   47,
#   56,
#   46,
#   60,
#   69,
#   24,
#   27,
#   23,
#   30,
#   32,
#   21,
#   64,
#   35,
#   25,
#   50,
#   20,
#   46,
#   20,
#   45,
#   19,
#   36,
#   23,
#   29,
#   38,
#   50,
#   44,
#   53,
#   49,
#   43,
#   51,
#   19,
#   53,
#   53,
#   25,
#   33,
#   57,
#   28,
#   26,
#   62,
#   33,
#   49,
#   26,
#   27,
#   40,
#   55,
#   23,
#   57,
#   21,
#   54,
#   52,
#   48,
#   23,
#   60,
#   73,
#   62,
#   48,
#   43,
#   46,
#   57,
#   69,
#   56,
#   61,
#   82,
#   25,
#   38,
#   28,
#   62,
#   24,
#   31,
#   53,
#   20,
#   61,
#   32,
#   41,
#   36,
#   21,
#   41,
#   61,
#   64,
#   76,
#   56,
#   60,
#   53,
#   20,
#   58,
#   41,
#   56,
#   23,
#   71,
#   57,
#   59,
#   60,
#   58,
#   33,
#   41,
#   38,
#   54,
#   48,
#   22,
#   60,
#   38,
#   58,
#   64,
#   28,
#   63,
#   73,
#   58,
#   41,
#   51,
#   43,
#   62,
#   57,
#   44,
#   29,
#   78,
#   45,
#   55,
#   22,
#   52,
#   17,
#   67,
#   37,
#   42,
#   62,
#   29,
#   80,
#   77,
#   22,
#   18,
#   40,
#   52,
#   67,
#   45,
#   59,
#   33,
#   28,
#   56,
#   39,
#   20,
#   31,
#   56,
#   36,
#   78,
#   49,
#   28,
#   43,
#   45,
#   45,
#   27,
#   68,
#   27,
#   23,
#   35,
#   74,
#   53,
#   58,
#   50,
#   19,
#   33,
#   33,
#   21,
#   36,
#   24,
#   32,
#   29,
#   78,
#   73,
#   52,
#   31,
#   30,
#   53,
#   44,
#   39,
#   23,
#   44,
#   73,
#   76,
#   63,
#   64,
#   56,
#   26,
#   40,
#   32,
#   76,
#   65,
#   46,
#   67,
#   33,
#   44,
#   71,
#   46,
#   55,
#   35,
#   52,
#   47,
#   65,
#   49,
#   49,
#   48,
#   56,
#   55,
#   53,
#   50,
#   42,
#   60,
#   35,
#   53,
#   68,
#   52,
#   59,
#   40,
#   34,
#   61,
#   70,
#   34,
#   32,
#   56,
#   57,
#   63,
#   64,
#   49,
#   40,
#   77,
#   22,
#   57,
#   46,
#   60,
#   32,
#   54,
#   84,
#   50,
#   61,
#   56,
#   25,
#   30,
#   77,
#   27,
#   31,
#   53,
#   28,
#   68,
#   18,
#   81,
#   27,
#   64,
#   26,
#   48,
#   61,
#   51,
#   59,
#   74,
#   57,
#   36,
#   58,
#   52,
#   63,
#   63,
#   31,
#   37,
#   30,
#   23,
#   45,
#   50,
#   33,
#   31,
#   23,
#   31,
#   68,
#   59,
#   41,
#   25,
#   69,
#   56,
#   57,
#   42,
#   69,
#   31,
#   48,
#   75,
#   26,
#   33,
#   27,
#   46,
#   38,
#   68,
#   35,
#   38,
#   62,
#   29,
#   60,
#   28,
#   30,
#   60,
#   51,
#   78,
#   47,
#   35,
#   56,
#   41,
#   67,
#   61,
#   18,
#   23,
#   27,
#   29,
#   25,
#   70,
#   58,
#   45,
#   64,
#   21,
#   51,
#   42,
#   43,
#   57,
#   74,
#   42,
#   53,
#   44,
#   31,
#   32,
#   55,
#   32,
#   47,
#   39,
#   74,
#   21,
#   67,
#   61,
#   47,
#   23,
#   66,
#   62,
#   73,
#   41,
#   38,
#   24,
#   69,
#   59,
#   23,
#   57,
#   24,
#   69,
#   60,
#   57,
#   56,
#   58,
#   51,
#   68,
#   61,
#   22,
#   64,
#   28,
#   25,
#   31,
#   67,
#   31,
#   63,
#   75,
#   46,
#   25,
#   48,
#   46,
#   24,
#   59,
#   73,
#   45,
#   47,
#   33,
#   71,
#   31,
#   47,
#   46,
#   54,
#   19,
#   29,
#   50,
#   22,
#   60,
#   58,
#   49,
#   25,
#   48,
#   28,
#   32,
#   38,
#   45,
#   22,
#   69,
#   44,
#   47,
#   29,
#   17,
#   69,
#   21,
#   18,
#   61,
#   28,
#   32,
#   62,
#   28,
#   47,
#   42,
#   46,
#   44,
#   22,
#   67,
#   43,
#   66,
#   31,
#   41,
#   31,
#   67,
#   50,
#   38,
#   52,
#   52,
#   36,
#   71,
#   72,
#   67,
#   55,
#   30,
#   32,
#   33,
#   37,
#   53,
#   66,
#   24,
#   32,
#   70,
#   53,
#   31,
#   48,
#   37,
#   73,
#   36,
#   33,
#   44,
#   34,
#   36,
#   41,
#   66,
#   63,
#   24,
#   31,
#   65,
#   81,
#   31,
#   51,
#   45,
#   71,
#   59,
#   67,
#   51,
#   23,
#   25,
#   53,
#   46,
#   29,
#   60,
#   53,
#   64,
#   46,
#   28,
#   66,
#   40,
#   90,
#   66,
#   49,
#   79,
#   21,
#   56,
#   37,
#   22,
#   72,
#   56,
#   60,
#   48,
#   65,
#   39,
#   49,
#   46,
#   42,
#   25,
#   63,
#   54,
#   38,
#   50,
#   39,
#   44,
#   27,
#   54,
#   82,
#   63,
#   57,
#   55,
#   62,
#   37,
#   34,
#   52,
#   50,
#   18,
#   55,
#   76,
#   57,
#   76,
#   63,
#   79,
#   41,
#   24,
#   42,
#   60,
#   54,
#   23,
#   61,
#   58,
#   67,
#   43,
#   59,
#   32,
#   60,
#   47,
#   26,
#   54,
#   61,
#   60,
#   24,
#   59,
#   24,
#   55,
#   37,
#   78,
#   27,
#   28,
#   38,
#   51,
#   69,
#   49,
#   67,
#   55,
#   39,
#   18,
#   41,
#   50,
#   56,
#   33,
#   24,
#   52,
#   49,
#   23,
#   63,
#   38,
#   26,
#   30,
#   54,
#   66,
#   40,
#   39,
#   56,
#   25,
#   47,
#   32,
#   68,
#   51,
#   49,
#   46,
#   44,
#   38,
#   71,
#   36,
#   46,
#   40,
#   53,
#   33,
#   20,
#   33,
#   25,
#   30,
#   57,
#   35,
#   31,
#   84,
#   25,
#   42,
#   58,
#   29,
#   64,
#   59,
#   44,
#   35,
#   31,
#   60,
#   43,
#   42,
#   43,
#   47,
#   33,
#   50,
#   55,
#   41,
#   43,
#   45,
#   52,
#   42,
#   21,
#   27,
#   56,
#   34,
#   28,
#   48,
#   42,
#   47,
#   58,
#   61,
#   46,
#   68,
#   49,
#   21,
#   29,
#   62,
#   54,
#   19,
#   29,
#   27,
#   25,
#   65,
#   39,
#   23,
#   48,
#   54,
#   67,
#   90,
#   62,
#   66,
#   56,
#   82,
#   54,
#   66,
#   52,
#   51,
#   58,
#   24,
#   60,
#   61,
#   59,
#   42,
#   30,
#   32,
#   26,
#   59,
#   36,
#   57,
#   24,
#   53,
#   60,
#   48,
#   47,
#   23,
#   52,
#   33,
#   30,
#   24,
#   24,
#   58,
#   23,
#   54,
#   60,
#   50,
#   34,
#   61,
#   90,
#   21,
#   31,
#   55,
#   44,
#   46,
#   55,
#   34,
#   59,
#   41,
#   32,
#   61,
#   42,
#   73,
#   20,
#   46,
#   49,
#   42,
#   42,
#   54,
#   41,
#   23,
#   62,
#   74,
#   30,
#   19,
#   56,
#   53,
#   40,
#   41,
#   43,
#   63,
#   67,
#   46,
#   37,
#   53,
#   25,
#   68,
#   30,
#   59,
#   28,
#   54,
#   29,
#   19,
#   52,
#   76,
#   47,
#   54,
#   27,
#   27,
#   28,
#   41,
#   22,
#   37,
#   37,
#   62,
#   40,
#   37,
#   38,
#   31,
#   78,
#   27,
#   49,
#   72,
#   42,
#   33,
#   61,
#   46,
#   36,
#   36,
#   37,
#   66,
#   50,
#   56,
#   54,
#   59,
#   34,
#   49,
#   22,
#   49,
#   28,
#   61,
#   18,
#   64,
#   28,
#   27,
#   76,
#   26,
#   39,
#   19,
#   30,
#   36,
#   49,
#   ...],
#  'capital_gain': [31,
#   42,
#   30,
#   30,
#   44,
#   44,
#   32,
#   17,
#   28,
#   38,
#   40,
#   35,
#   36,
#   58,
#   66,
#   35,
#   59,
#   17,
#   50,
#   44,
#   24,
#   42,
#   57,
#   39,
#   48,
#   55,
#   34,
#   66,
#   38,
#   36,
#   34,
#   46,
#   17,
#   40,
#   34,
#   52,
#   38,
#   38,
#   50,
#   67,
#   43,
#   31,
#   25,
#   52,
#   26,
#   46,
#   43,
#   33,
#   36,
#   24,
#   70,
#   42,
#   27,
#   22,
#   46,
#   40,
#   29,
#   42,
#   65,
#   35,
#   56,
#   42,
#   55,
#   29,
#   21,
#   23,
#   32,
#   33,
#   53,
#   55,
#   71,
#   29,
#   37,
#   39,
#   37,
#   21,
#   78,
#   51,
#   40,
#   39,
#   54,
#   50,
#   66,
#   44,
#   30,
#   61,
#   42,
#   41,
#   45,
#   33,
#   50,
#   44,
#   65,
#   50,
#   44,
#   54,
#   48,
#   31,
#   54,
#   51,
#   67,
#   50,
#   47,
#   35,
#   61,
#   33,
#   71,
#   62,
#   32,
#   52,
#   65,
#   54,
#   51,
#   45,
#   39,
#   18,
#   45,
#   17,
#   25,
#   48,
#   40,
#   53,
#   31,
#   53,
#   49,
#   64,
#   30,
#   59,
#   52,
#   62,
#   75,
#   49,
#   39,
#   20,
#   55,
#   46,
#   52,
#   39,
#   28,
#   54,
#   48,
#   65,
#   44,
#   44,
#   51,
#   43,
#   17,
#   53,
#   24,
#   64,
#   46,
#   49,
#   71,
#   26,
#   50,
#   51,
#   43,
#   38,
#   31,
#   42,
#   39,
#   33,
#   41,
#   73,
#   35,
#   22,
#   45,
#   32,
#   61,
#   45,
#   46,
#   50,
#   26,
#   40,
#   36,
#   60,
#   66,
#   24,
#   34,
#   63,
#   37,
#   43,
#   66,
#   47,
#   57,
#   41,
#   65,
#   64,
#   59,
#   29,
#   53,
#   65,
#   23,
#   44,
#   18,
#   31,
#   37,
#   26,
#   36,
#   34,
#   37,
#   74,
#   56,
#   54,
#   45,
#   60,
#   38,
#   64,
#   39,
#   69,
#   44,
#   75,
#   50,
#   47,
#   51,
#   54,
#   58,
#   43,
#   56,
#   34,
#   41,
#   77,
#   39,
#   37,
#   52,
#   32,
#   47,
#   32,
#   40,
#   51,
#   55,
#   27,
#   47,
#   34,
#   52,
#   39,
#   40,
#   45,
#   25,
#   37,
#   38,
#   43,
#   57,
#   53,
#   34,
#   40,
#   44,
#   37,
#   38,
#   39,
#   81,
#   36,
#   34,
#   38,
#   64,
#   35,
#   39,
#   57,
#   35,
#   51,
#   46,
#   28,
#   44,
#   35,
#   25,
#   45,
#   33,
#   36,
#   71,
#   57,
#   39,
#   48,
#   64,
#   45,
#   52,
#   45,
#   49,
#   24,
#   36,
#   40,
#   47,
#   38,
#   51,
#   45,
#   41,
#   34,
#   46,
#   43,
#   50,
#   38,
#   31,
#   46,
#   59,
#   69,
#   26,
#   40,
#   52,
#   67,
#   51,
#   47,
#   19,
#   53,
#   61,
#   59,
#   17,
#   52,
#   31,
#   33,
#   34,
#   44,
#   33,
#   39,
#   58,
#   41,
#   27,
#   32,
#   36,
#   39,
#   37,
#   49,
#   26,
#   20,
#   52,
#   45,
#   62,
#   54,
#   38,
#   39,
#   49,
#   62,
#   36,
#   29,
#   44,
#   50,
#   33,
#   39,
#   90,
#   33,
#   34,
#   29,
#   39,
#   46,
#   47,
#   37,
#   35,
#   55,
#   53,
#   26,
#   75,
#   27,
#   32,
#   32,
#   66,
#   35,
#   34,
#   33,
#   51,
#   53,
#   53,
#   22,
#   27,
#   32,
#   48,
#   52,
#   53,
#   37,
#   37,
#   41,
#   35,
#   35,
#   41,
#   53,
#   38,
#   41,
#   18,
#   37,
#   57,
#   26,
#   47,
#   46,
#   48,
#   36,
#   47,
#   41,
#   30,
#   58,
#   45,
#   30,
#   37,
#   38,
#   33,
#   25,
#   39,
#   46,
#   45,
#   38,
#   31,
#   37,
#   25,
#   36,
#   28,
#   31,
#   66,
#   49,
#   67,
#   36,
#   42,
#   56,
#   68,
#   35,
#   29,
#   37,
#   45,
#   55,
#   23,
#   35,
#   26,
#   25,
#   46,
#   45,
#   47,
#   26,
#   63,
#   52,
#   21,
#   36,
#   25,
#   39,
#   37,
#   50,
#   28,
#   42,
#   54,
#   41,
#   49,
#   41,
#   36,
#   38,
#   51,
#   32,
#   25,
#   63,
#   30,
#   28,
#   90,
#   35,
#   50,
#   53,
#   44,
#   45,
#   39,
#   47,
#   44,
#   41,
#   61,
#   25,
#   33,
#   40,
#   42,
#   34,
#   43,
#   47,
#   42,
#   57,
#   26,
#   36,
#   62,
#   53,
#   71,
#   31,
#   56,
#   39,
#   45,
#   56,
#   60,
#   50,
#   32,
#   45,
#   35,
#   39,
#   35,
#   48,
#   59,
#   41,
#   36,
#   36,
#   42,
#   30,
#   55,
#   42,
#   52,
#   64,
#   51,
#   52,
#   51,
#   34,
#   67,
#   65,
#   34,
#   78,
#   61,
#   65,
#   47,
#   48,
#   45,
#   47,
#   79,
#   33,
#   35,
#   36,
#   90,
#   67,
#   22,
#   51,
#   20,
#   50,
#   40,
#   29,
#   36,
#   50,
#   33,
#   47,
#   18,
#   33,
#   74,
#   34,
#   41,
#   27,
#   17,
#   42,
#   52,
#   53,
#   43,
#   49,
#   39,
#   35,
#   51,
#   49,
#   35,
#   25,
#   21,
#   75,
#   55,
#   26,
#   45,
#   19,
#   43,
#   39,
#   56,
#   57,
#   47,
#   46,
#   51,
#   42,
#   61,
#   48,
#   28,
#   31,
#   39,
#   54,
#   63,
#   63,
#   35,
#   46,
#   52,
#   49,
#   44,
#   36,
#   60,
#   65,
#   67,
#   69,
#   32,
#   32,
#   63,
#   55,
#   63,
#   31,
#   58,
#   18,
#   56,
#   44,
#   52,
#   58,
#   30,
#   38,
#   41,
#   46,
#   47,
#   52,
#   39,
#   19,
#   64,
#   63,
#   40,
#   49,
#   47,
#   31,
#   46,
#   37,
#   39,
#   25,
#   29,
#   20,
#   24,
#   44,
#   46,
#   47,
#   36,
#   36,
#   24,
#   54,
#   29,
#   39,
#   47,
#   35,
#   32,
#   33,
#   41,
#   36,
#   51,
#   63,
#   39,
#   43,
#   38,
#   38,
#   43,
#   37,
#   32,
#   26,
#   37,
#   40,
#   37,
#   47,
#   58,
#   69,
#   33,
#   36,
#   29,
#   41,
#   26,
#   36,
#   36,
#   37,
#   40,
#   35,
#   39,
#   31,
#   58,
#   35,
#   34,
#   67,
#   34,
#   37,
#   41,
#   51,
#   38,
#   36,
#   50,
#   57,
#   31,
#   44,
#   23,
#   29,
#   53,
#   63,
#   39,
#   43,
#   34,
#   37,
#   48,
#   26,
#   49,
#   46,
#   69,
#   54,
#   64,
#   51,
#   61,
#   26,
#   35,
#   39,
#   62,
#   53,
#   31,
#   35,
#   26,
#   31,
#   43,
#   47,
#   78,
#   28,
#   30,
#   38,
#   23,
#   70,
#   34,
#   33,
#   35,
#   19,
#   29,
#   51,
#   38,
#   28,
#   32,
#   30,
#   48,
#   32,
#   39,
#   23,
#   29,
#   80,
#   48,
#   52,
#   67,
#   47,
#   52,
#   22,
#   25,
#   36,
#   30,
#   41,
#   50,
#   39,
#   36,
#   55,
#   56,
#   57,
#   39,
#   90,
#   47,
#   35,
#   41,
#   69,
#   37,
#   37,
#   53,
#   45,
#   32,
#   32,
#   43,
#   90,
#   23,
#   43,
#   56,
#   50,
#   41,
#   24,
#   34,
#   37,
#   54,
#   38,
#   68,
#   35,
#   77,
#   44,
#   21,
#   21,
#   72,
#   32,
#   25,
#   33,
#   41,
#   46,
#   19,
#   41,
#   38,
#   72,
#   35,
#   31,
#   59,
#   43,
#   40,
#   45,
#   64,
#   54,
#   27,
#   32,
#   40,
#   70,
#   40,
#   46,
#   37,
#   42,
#   36,
#   27,
#   43,
#   41,
#   22,
#   55,
#   60,
#   53,
#   39,
#   44,
#   41,
#   37,
#   49,
#   26,
#   24,
#   47,
#   48,
#   49,
#   35,
#   51,
#   31,
#   38,
#   30,
#   37,
#   57,
#   39,
#   36,
#   52,
#   56,
#   58,
#   59,
#   38,
#   76,
#   68,
#   34,
#   47,
#   63,
#   33,
#   41,
#   43,
#   73,
#   28,
#   20,
#   34,
#   29,
#   18,
#   43,
#   50,
#   51,
#   59,
#   24,
#   36,
#   48,
#   56,
#   40,
#   29,
#   54,
#   39,
#   51,
#   42,
#   48,
#   69,
#   48,
#   61,
#   32,
#   32,
#   43,
#   67,
#   34,
#   29,
#   45,
#   65,
#   63,
#   31,
#   52,
#   49,
#   23,
#   35,
#   47,
#   90,
#   26,
#   69,
#   38,
#   59,
#   18,
#   40,
#   44,
#   57,
#   71,
#   64,
#   58,
#   68,
#   33,
#   36,
#   42,
#   36,
#   46,
#   34,
#   30,
#   67,
#   45,
#   58,
#   20,
#   65,
#   29,
#   37,
#   35,
#   50,
#   21,
#   32,
#   25,
#   33,
#   36,
#   35,
#   32,
#   47,
#   53,
#   21,
#   36,
#   21,
#   56,
#   54,
#   60,
#   28,
#   66,
#   45,
#   54,
#   49,
#   48,
#   46,
#   52,
#   48,
#   40,
#   52,
#   24,
#   32,
#   28,
#   42,
#   25,
#   32,
#   47,
#   47,
#   62,
#   51,
#   37,
#   66,
#   70,
#   54,
#   59,
#   51,
#   36,
#   65,
#   37,
#   53,
#   28,
#   44,
#   44,
#   45,
#   25,
#   38,
#   23,
#   69,
#   43,
#   41,
#   43,
#   47,
#   62,
#   51,
#   53,
#   40,
#   54,
#   47,
#   30,
#   40,
#   47,
#   30,
#   29,
#   35,
#   26,
#   28,
#   67,
#   26,
#   61,
#   90,
#   37,
#   69,
#   57,
#   78,
#   40,
#   38,
#   35,
#   36,
#   59,
#   49,
#   31,
#   26,
#   47,
#   34,
#   34,
#   25,
#   50,
#   51,
#   53,
#   33,
#   30,
#   20,
#   46,
#   46,
#   45,
#   37,
#   39,
#   52,
#   24,
#   36,
#   43,
#   72,
#   ...],
#  'capital_lost': [43,
#   45,
#   47,
#   30,
#   48,
#   56,
#   20,
#   24,
#   45,
#   64,
#   71,
#   27,
#   51,
#   26,
#   42,
#   90,
#   38,
#   40,
#   43,
#   43,
#   43,
#   46,
#   44,
#   28,
#   41,
#   28,
#   36,
#   27,
#   49,
#   49,
#   37,
#   52,
#   42,
#   20,
#   24,
#   31,
#   31,
#   41,
#   26,
#   28,
#   61,
#   43,
#   24,
#   32,
#   57,
#   51,
#   41,
#   36,
#   67,
#   46,
#   50,
#   20,
#   19,
#   36,
#   49,
#   35,
#   38,
#   48,
#   27,
#   29,
#   39,
#   60,
#   50,
#   46,
#   28,
#   38,
#   46,
#   52,
#   26,
#   61,
#   40,
#   40,
#   59,
#   57,
#   50,
#   56,
#   35,
#   30,
#   35,
#   25,
#   26,
#   62,
#   41,
#   44,
#   44,
#   45,
#   49,
#   37,
#   37,
#   51,
#   43,
#   21,
#   59,
#   46,
#   34,
#   29,
#   42,
#   30,
#   45,
#   37,
#   31,
#   30,
#   57,
#   32,
#   28,
#   42,
#   49,
#   42,
#   45,
#   37,
#   44,
#   38,
#   38,
#   19,
#   23,
#   18,
#   45,
#   39,
#   53,
#   51,
#   67,
#   42,
#   39,
#   35,
#   25,
#   53,
#   44,
#   66,
#   68,
#   55,
#   42,
#   39,
#   31,
#   34,
#   45,
#   42,
#   26,
#   30,
#   43,
#   49,
#   61,
#   47,
#   24,
#   58,
#   45,
#   41,
#   40,
#   67,
#   31,
#   33,
#   49,
#   50,
#   48,
#   57,
#   24,
#   42,
#   31,
#   61,
#   20,
#   48,
#   60,
#   65,
#   42,
#   55,
#   51,
#   32,
#   45,
#   49,
#   53,
#   42,
#   38,
#   31,
#   34,
#   20,
#   32,
#   41,
#   30,
#   26,
#   40,
#   43,
#   56,
#   68,
#   43,
#   43,
#   72,
#   32,
#   39,
#   42,
#   37,
#   34,
#   28,
#   41,
#   38,
#   28,
#   80,
#   33,
#   48,
#   45,
#   43,
#   41,
#   50,
#   53,
#   56,
#   24,
#   42,
#   49,
#   48,
#   37,
#   72,
#   36,
#   35,
#   19,
#   33,
#   40,
#   41,
#   45,
#   46,
#   41,
#   34,
#   27,
#   49,
#   59,
#   44,
#   31,
#   67,
#   35,
#   24,
#   43,
#   49,
#   46,
#   25,
#   43,
#   47,
#   34,
#   59,
#   34,
#   31,
#   30,
#   65,
#   40,
#   30,
#   51,
#   40,
#   20,
#   25,
#   23,
#   32,
#   50,
#   36,
#   44,
#   54,
#   31,
#   49,
#   44,
#   30,
#   55,
#   45,
#   42,
#   55,
#   57,
#   57,
#   28,
#   49,
#   28,
#   27,
#   63,
#   41,
#   39,
#   57,
#   33,
#   42,
#   41,
#   35,
#   29,
#   23,
#   21,
#   67,
#   28,
#   34,
#   30,
#   59,
#   38,
#   19,
#   30,
#   69,
#   38,
#   54,
#   26,
#   19,
#   22,
#   34,
#   31,
#   42,
#   37,
#   43,
#   51,
#   25,
#   40,
#   54,
#   36,
#   55,
#   55,
#   32,
#   52,
#   34,
#   51,
#   58,
#   46,
#   50,
#   46,
#   64,
#   20,
#   30,
#   62,
#   38,
#   44,
#   55,
#   21,
#   33,
#   23,
#   25,
#   46,
#   43,
#   31,
#   39,
#   31,
#   31,
#   39,
#   39,
#   61,
#   41,
#   33,
#   59,
#   35,
#   60,
#   25,
#   57,
#   47,
#   27,
#   51,
#   59,
#   55,
#   46,
#   23,
#   36,
#   42,
#   45,
#   38,
#   37,
#   63,
#   52,
#   29,
#   25,
#   26,
#   34,
#   47,
#   48,
#   37,
#   46,
#   53,
#   32,
#   21,
#   38,
#   37,
#   51,
#   51,
#   46,
#   60,
#   35,
#   31,
#   65,
#   40,
#   27,
#   58,
#   31,
#   52,
#   48,
#   47,
#   68,
#   29,
#   33,
#   26,
#   35,
#   46,
#   50,
#   40,
#   66,
#   53,
#   22,
#   40,
#   39,
#   44,
#   39,
#   34,
#   42,
#   20,
#   40,
#   73,
#   65,
#   50,
#   62,
#   43,
#   43,
#   42,
#   51,
#   43,
#   45,
#   30,
#   69,
#   31,
#   52,
#   29,
#   45,
#   28,
#   42,
#   19,
#   23,
#   24,
#   32,
#   60,
#   32,
#   25,
#   40,
#   46,
#   18,
#   31,
#   41,
#   41,
#   46,
#   57,
#   90,
#   32,
#   58,
#   46,
#   28,
#   42,
#   29,
#   70,
#   20,
#   51,
#   34,
#   47,
#   50,
#   28,
#   39,
#   50,
#   41,
#   22,
#   48,
#   52,
#   36,
#   53,
#   46,
#   21,
#   42,
#   25,
#   58,
#   44,
#   46,
#   31,
#   38,
#   42,
#   70,
#   41,
#   34,
#   39,
#   29,
#   35,
#   20,
#   44,
#   36,
#   47,
#   47,
#   61,
#   49,
#   50,
#   32,
#   31,
#   52,
#   59,
#   44,
#   47,
#   40,
#   25,
#   27,
#   39,
#   65,
#   36,
#   42,
#   18,
#   27,
#   74,
#   56,
#   39,
#   29,
#   41,
#   38,
#   51,
#   23,
#   57,
#   51,
#   37,
#   32,
#   65,
#   55,
#   26,
#   25,
#   51,
#   30,
#   28,
#   72,
#   52,
#   38,
#   28,
#   52,
#   60,
#   50,
#   34,
#   43,
#   34,
#   34,
#   36,
#   49,
#   49,
#   55,
#   45,
#   41,
#   39,
#   47,
#   46,
#   46,
#   46,
#   33,
#   27,
#   32,
#   66,
#   53,
#   30,
#   25,
#   38,
#   35,
#   63,
#   75,
#   50,
#   41,
#   32,
#   48,
#   34,
#   59,
#   52,
#   33,
#   30,
#   33,
#   43,
#   27,
#   41,
#   71,
#   27,
#   23,
#   49,
#   20,
#   44,
#   19,
#   47,
#   37,
#   35,
#   31,
#   41,
#   59,
#   33,
#   34,
#   57,
#   44,
#   32,
#   24,
#   44,
#   46,
#   36,
#   53,
#   46,
#   54,
#   55,
#   54,
#   39,
#   33,
#   53,
#   39,
#   55,
#   52,
#   47,
#   52,
#   21,
#   60,
#   46,
#   61,
#   32,
#   50,
#   39,
#   22,
#   59,
#   23,
#   59,
#   46,
#   45,
#   35,
#   42,
#   65,
#   44,
#   49,
#   74,
#   51,
#   50,
#   38,
#   33,
#   39,
#   46,
#   37,
#   46,
#   37,
#   44,
#   45,
#   32,
#   61,
#   50,
#   32,
#   37,
#   78,
#   39,
#   57,
#   41,
#   49,
#   30,
#   54,
#   42,
#   33,
#   25,
#   47,
#   56,
#   32,
#   30,
#   47,
#   43,
#   54,
#   54,
#   21,
#   50,
#   46,
#   51,
#   45,
#   36,
#   43,
#   42,
#   51,
#   27,
#   59,
#   39,
#   34,
#   36,
#   34,
#   42,
#   37,
#   47,
#   81,
#   47,
#   41,
#   40,
#   29,
#   57,
#   53,
#   32,
#   41,
#   25,
#   17,
#   39,
#   42,
#   39,
#   22,
#   31,
#   45,
#   41,
#   21,
#   38,
#   46,
#   29,
#   35,
#   19,
#   60,
#   38,
#   55,
#   49,
#   56,
#   82,
#   48,
#   39,
#   59,
#   34,
#   29,
#   42,
#   32,
#   37,
#   19,
#   51,
#   34,
#   52,
#   55,
#   51,
#   35,
#   28,
#   31,
#   47,
#   31,
#   47,
#   47,
#   27,
#   39,
#   41,
#   57,
#   35,
#   31,
#   30,
#   41,
#   45,
#   26,
#   40,
#   33,
#   75,
#   50,
#   45,
#   28,
#   32,
#   43,
#   66,
#   27,
#   31,
#   60,
#   48,
#   18,
#   39,
#   56,
#   41,
#   53,
#   41,
#   34,
#   44,
#   60,
#   47,
#   45,
#   34,
#   32,
#   58,
#   58,
#   38,
#   28,
#   44,
#   38,
#   40,
#   18,
#   57,
#   58,
#   39,
#   50,
#   39,
#   36,
#   28,
#   31,
#   34,
#   27,
#   46,
#   28,
#   59,
#   51,
#   26,
#   46,
#   26,
#   48,
#   44,
#   61,
#   30,
#   39,
#   27,
#   49,
#   39,
#   26,
#   47,
#   55,
#   28,
#   34,
#   64,
#   31,
#   37,
#   45,
#   31,
#   55,
#   23,
#   37,
#   62,
#   42,
#   43,
#   61,
#   60,
#   49,
#   46,
#   44,
#   48,
#   34,
#   21,
#   41,
#   41,
#   63,
#   38,
#   73,
#   40,
#   59,
#   29,
#   44,
#   31,
#   53,
#   70,
#   57,
#   27,
#   39,
#   39,
#   45,
#   38,
#   39,
#   69,
#   53,
#   48,
#   49,
#   26,
#   28,
#   46,
#   49,
#   46,
#   40,
#   21,
#   51,
#   31,
#   42,
#   54,
#   44,
#   38,
#   54,
#   39,
#   29,
#   23,
#   21,
#   58,
#   28,
#   34,
#   21,
#   36,
#   39,
#   60,
#   43,
#   39,
#   30,
#   36,
#   44,
#   30,
#   23,
#   46,
#   36,
#   49,
#   48,
#   30,
#   27,
#   22,
#   45,
#   39,
#   30,
#   18,
#   34,
#   49,
#   43,
#   35,
#   19,
#   51,
#   48,
#   37,
#   56,
#   24,
#   25,
#   70,
#   26,
#   46,
#   34,
#   37,
#   43,
#   45,
#   44,
#   46,
#   45,
#   25,
#   35,
#   47,
#   53,
#   52,
#   41,
#   31,
#   53,
#   24,
#   31,
#   18,
#   45,
#   41,
#   17,
#   37,
#   30,
#   17,
#   37,
#   55,
#   39,
#   32,
#   32,
#   30,
#   38,
#   23,
#   44,
#   55,
#   53,
#   29,
#   30,
#   39,
#   27,
#   37,
#   51,
#   41,
#   33,
#   32,
#   27,
#   68,
#   31,
#   32,
#   23,
#   58,
#   34,
#   36,
#   46,
#   47,
#   45,
#   42,
#   29,
#   40,
#   67,
#   47,
#   45,
#   26,
#   39,
#   42,
#   33,
#   25,
#   25,
#   19,
#   25,
#   65,
#   28,
#   46,
#   41,
#   28,
#   41,
#   41,
#   54,
#   42,
#   24,
#   57,
#   17,
#   44,
#   36,
#   39,
#   43,
#   44,
#   51,
#   52,
#   73,
#   42,
#   42,
#   36,
#   39,
#   42,
#   50,
#   30,
#   33,
#   46,
#   56,
#   44,
#   53,
#   51,
#   34,
#   77,
#   34,
#   47,
#   21,
#   35,
#   25,
#   30,
#   42,
#   56,
#   54,
#   33,
#   ...],
#  'hours_week': [50,
#   49,
#   37,
#   23,
#   40,
#   54,
#   54,
#   39,
#   22,
#   19,
#   18,
#   47,
#   50,
#   47,
#   29,
#   19,
#   29,
#   79,
#   67,
#   18,
#   18,
#   28,
#   48,
#   44,
#   17,
#   28,
#   55,
#   40,
#   20,
#   28,
#   43,
#   20,
#   19,
#   31,
#   22,
#   36,
#   71,
#   29,
#   68,
#   18,
#   66,
#   27,
#   18,
#   33,
#   58,
#   38,
#   41,
#   40,
#   35,
#   17,
#   37,
#   45,
#   54,
#   60,
#   75,
#   28,
#   38,
#   41,
#   20,
#   40,
#   59,
#   58,
#   32,
#   45,
#   17,
#   37,
#   19,
#   17,
#   50,
#   22,
#   41,
#   29,
#   65,
#   37,
#   38,
#   21,
#   41,
#   19,
#   22,
#   62,
#   76,
#   23,
#   66,
#   49,
#   19,
#   33,
#   67,
#   56,
#   31,
#   46,
#   36,
#   22,
#   22,
#   26,
#   17,
#   20,
#   46,
#   23,
#   44,
#   19,
#   25,
#   34,
#   41,
#   46,
#   41,
#   46,
#   30,
#   20,
#   17,
#   25,
#   23,
#   80,
#   30,
#   34,
#   45,
#   17,
#   45,
#   23,
#   24,
#   37,
#   30,
#   30,
#   67,
#   17,
#   22,
#   43,
#   28,
#   25,
#   38,
#   35,
#   34,
#   33,
#   72,
#   19,
#   53,
#   25,
#   20,
#   38,
#   44,
#   74,
#   57,
#   58,
#   31,
#   34,
#   28,
#   52,
#   17,
#   27,
#   18,
#   65,
#   21,
#   29,
#   57,
#   23,
#   19,
#   17,
#   52,
#   27,
#   39,
#   50,
#   52,
#   23,
#   45,
#   65,
#   29,
#   30,
#   38,
#   49,
#   43,
#   58,
#   19,
#   33,
#   52,
#   26,
#   71,
#   20,
#   27,
#   70,
#   35,
#   20,
#   17,
#   17,
#   17,
#   18,
#   66,
#   45,
#   26,
#   20,
#   23,
#   35,
#   19,
#   21,
#   46,
#   18,
#   22,
#   41,
#   20,
#   65,
#   23,
#   25,
#   56,
#   19,
#   55,
#   17,
#   22,
#   36,
#   53,
#   51,
#   22,
#   37,
#   31,
#   37,
#   23,
#   41,
#   40,
#   18,
#   59,
#   60,
#   22,
#   24,
#   68,
#   17,
#   20,
#   17,
#   47,
#   41,
#   32,
#   39,
#   43,
#   42,
#   72,
#   63,
#   17,
#   31,
#   26,
#   49,
#   18,
#   28,
#   24,
#   17,
#   55,
#   41,
#   23,
#   19,
#   27,
#   33,
#   63,
#   23,
#   33,
#   48,
#   42,
#   47,
#   63,
#   51,
#   24,
#   37,
#   27,
#   53,
#   81,
#   21,
#   23,
#   64,
#   51,
#   42,
#   19,
#   37,
#   47,
#   33,
#   18,
#   41,
#   44,
#   32,
#   20,
#   35,
#   55,
#   36,
#   44,
#   63,
#   50,
#   56,
#   48,
#   50,
#   23,
#   31,
#   38,
#   51,
#   19,
#   42,
#   45,
#   20,
#   76,
#   66,
#   37,
#   34,
#   34,
#   44,
#   28,
#   64,
#   52,
#   30,
#   54,
#   49,
#   35,
#   36,
#   22,
#   17,
#   19,
#   58,
#   38,
#   31,
#   22,
#   29,
#   68,
#   45,
#   34,
#   29,
#   41,
#   60,
#   35,
#   27,
#   19,
#   56,
#   30,
#   25,
#   51,
#   34,
#   20,
#   33,
#   65,
#   22,
#   25,
#   20,
#   22,
#   65,
#   24,
#   39,
#   19,
#   51,
#   59,
#   45,
#   22,
#   44,
#   37,
#   31,
#   20,
#   38,
#   36,
#   42,
#   23,
#   34,
#   31,
#   55,
#   65,
#   38,
#   62,
#   54,
#   48,
#   69,
#   28,
#   67,
#   21,
#   63,
#   39,
#   21,
#   29,
#   20,
#   35,
#   20,
#   55,
#   17,
#   24,
#   57,
#   33,
#   71,
#   17,
#   36,
#   61,
#   40,
#   22,
#   61,
#   43,
#   44,
#   37,
#   40,
#   17,
#   59,
#   50,
#   55,
#   42,
#   43,
#   52,
#   28,
#   31,
#   18,
#   50,
#   61,
#   56,
#   44,
#   17,
#   46,
#   76,
#   41,
#   49,
#   24,
#   61,
#   69,
#   17,
#   26,
#   25,
#   37,
#   35,
#   36,
#   37,
#   64,
#   20,
#   30,
#   46,
#   59,
#   17,
#   26,
#   20,
#   37,
#   26,
#   62,
#   17,
#   17,
#   23,
#   25,
#   21,
#   18,
#   75,
#   20,
#   24,
#   72,
#   22,
#   65,
#   38,
#   33,
#   33,
#   19,
#   22,
#   36,
#   26,
#   46,
#   48,
#   52,
#   36,
#   39,
#   67,
#   34,
#   55,
#   71,
#   35,
#   19,
#   36,
#   18,
#   55,
#   50,
#   46,
#   20,
#   37,
#   26,
#   43,
#   20,
#   17,
#   54,
#   18,
#   73,
#   51,
#   21,
#   24,
#   21,
#   57,
#   45,
#   50,
#   43,
#   42,
#   38,
#   47,
#   40,
#   19,
#   49,
#   71,
#   17,
#   17,
#   73,
#   57,
#   51,
#   51,
#   19,
#   45,
#   21,
#   46,
#   70,
#   63,
#   44,
#   18,
#   26,
#   38,
#   60,
#   23,
#   46,
#   31,
#   21,
#   42,
#   55,
#   25,
#   62,
#   34,
#   45,
#   42,
#   47,
#   44,
#   30,
#   57,
#   18,
#   37,
#   29,
#   77,
#   28,
#   21,
#   30,
#   33,
#   28,
#   47,
#   49,
#   37,
#   27,
#   28,
#   23,
#   31,
#   34,
#   63,
#   41,
#   27,
#   53,
#   17,
#   23,
#   22,
#   18,
#   19,
#   20,
#   37,
#   40,
#   28,
#   37,
#   26,
#   61,
#   43,
#   30,
#   21,
#   37,
#   45,
#   61,
#   42,
#   23,
#   20,
#   35,
#   41,
#   27,
#   46,
#   29,
#   21,
#   75,
#   57,
#   47,
#   17,
#   61,
#   47,
#   22,
#   59,
#   41,
#   35,
#   63,
#   24,
#   29,
#   74,
#   50,
#   65,
#   28,
#   31,
#   34,
#   60,
#   22,
#   20,
#   23,
#   37,
#   58,
#   44,
#   20,
#   31,
#   23,
#   19,
#   17,
#   29,
#   21,
#   18,
#   41,
#   34,
#   42,
#   18,
#   18,
#   22,
#   41,
#   43,
#   26,
#   56,
#   62,
#   65,
#   22,
#   23,
#   23,
#   35,
#   51,
#   19,
#   22,
#   27,
#   23,
#   36,
#   22,
#   28,
#   22,
#   67,
#   34,
#   26,
#   61,
#   17,
#   19,
#   30,
#   22,
#   53,
#   34,
#   70,
#   36,
#   55,
#   68,
#   29,
#   36,
#   31,
#   20,
#   61,
#   19,
#   29,
#   25,
#   35,
#   31,
#   69,
#   48,
#   39,
#   39,
#   69,
#   74,
#   75,
#   76,
#   18,
#   19,
#   32,
#   31,
#   57,
#   59,
#   70,
#   51,
#   36,
#   47,
#   49,
#   21,
#   20,
#   34,
#   63,
#   24,
#   25,
#   22,
#   43,
#   39,
#   54,
#   19,
#   24,
#   29,
#   21,
#   32,
#   47,
#   52,
#   77,
#   67,
#   35,
#   32,
#   18,
#   45,
#   18,
#   25,
#   74,
#   25,
#   42,
#   45,
#   32,
#   40,
#   55,
#   66,
#   21,
#   55,
#   37,
#   18,
#   26,
#   48,
#   70,
#   38,
#   23,
#   62,
#   26,
#   78,
#   42,
#   64,
#   27,
#   47,
#   18,
#   18,
#   21,
#   46,
#   42,
#   34,
#   19,
#   54,
#   62,
#   49,
#   57,
#   32,
#   20,
#   55,
#   43,
#   80,
#   43,
#   56,
#   34,
#   34,
#   41,
#   55,
#   49,
#   27,
#   40,
#   43,
#   54,
#   44,
#   34,
#   47,
#   17,
#   35,
#   33,
#   18,
#   44,
#   41,
#   53,
#   40,
#   24,
#   18,
#   39,
#   38,
#   36,
#   63,
#   57,
#   17,
#   69,
#   37,
#   36,
#   20,
#   54,
#   28,
#   35,
#   29,
#   25,
#   47,
#   71,
#   56,
#   45,
#   22,
#   67,
#   81,
#   17,
#   28,
#   40,
#   63,
#   42,
#   35,
#   21,
#   32,
#   23,
#   28,
#   17,
#   18,
#   45,
#   22,
#   34,
#   48,
#   68,
#   37,
#   27,
#   29,
#   22,
#   55,
#   23,
#   20,
#   35,
#   39,
#   37,
#   38,
#   72,
#   55,
#   33,
#   19,
#   44,
#   21,
#   24,
#   42,
#   47,
#   40,
#   30,
#   61,
#   71,
#   44,
#   46,
#   27,
#   40,
#   61,
#   54,
#   53,
#   39,
#   30,
#   35,
#   69,
#   21,
#   72,
#   20,
#   35,
#   18,
#   38,
#   23,
#   20,
#   44,
#   46,
#   60,
#   46,
#   65,
#   20,
#   18,
#   45,
#   20,
#   35,
#   52,
#   35,
#   25,
#   22,
#   44,
#   24,
#   64,
#   31,
#   43,
#   35,
#   39,
#   51,
#   71,
#   37,
#   39,
#   50,
#   59,
#   82,
#   49,
#   74,
#   32,
#   59,
#   47,
#   44,
#   42,
#   56,
#   26,
#   23,
#   30,
#   31,
#   21,
#   73,
#   40,
#   19,
#   29,
#   34,
#   74,
#   22,
#   19,
#   61,
#   50,
#   26,
#   68,
#   26,
#   32,
#   63,
#   45,
#   79,
#   57,
#   41,
#   20,
#   30,
#   26,
#   29,
#   20,
#   40,
#   38,
#   21,
#   38,
#   51,
#   51,
#   20,
#   18,
#   53,
#   66,
#   35,
#   34,
#   19,
#   40,
#   23,
#   39,
#   46,
#   17,
#   63,
#   50,
#   18,
#   22,
#   21,
#   55,
#   31,
#   17,
#   39,
#   38,
#   50,
#   18,
#   31,
#   35,
#   18,
#   35,
#   18,
#   19,
#   45,
#   21,
#   31,
#   17,
#   32,
#   21,
#   81,
#   39,
#   23,
#   23,
#   17,
#   67,
#   30,
#   56,
#   57,
#   19,
#   68,
#   17,
#   37,
#   21,
#   27,
#   25,
#   74,
#   31,
#   19,
#   39,
#   19,
#   72,
#   17,
#   73,
#   23,
#   65,
#   24,
#   37,
#   63,
#   27,
#   35,
#   22,
#   76,
#   21,
#   34,
#   42,
#   21,
#   55,
#   62,
#   31,
#   75,
#   39,
#   18,
#   35,
#   70,
#   70,
#   58,
#   53,
#   22,
#   41,
#   42,
#   21,
#   19,
#   38,
#   38,
#   64,
#   18,
#   ...]}

# %%
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# final_weight   32560.0  189781.814373  105549.764924  12285.0  117831.5
# education_num  32560.0      10.080590       2.572709      1.0       9.0
# capital_gain   32560.0    1077.615172    7385.402999      0.0       0.0
# capital_lost   32560.0      87.306511     402.966116      0.0       0.0
# hours_week     32560.0      40.437469      12.347618      1.0      40.0
#
#                     50%       75%        max
# final_weight   178363.0  237054.5  1484705.0
# education_num      10.0      12.0       16.0
# capital_gain        0.0       0.0    99999.0
# capital_lost        0.0       0.0     4356.0
# hours_week         40.0      45.0       99.0

# %%
# Outliers visualmente:

fig, axes = plt.subplots(5, figsize=(15,25))

axes = axes.flat

for indice, columna in enumerate(numericas.columns):
    sns.boxplot(x = numericas[columna], data = df, ax=axes[indice], color = "aquamarine"); # para trazar una línea de densidad

    
plt.tight_layout()
plt.show()

# %%
indices.keys()
# Out:
# dict_keys(['final_weight', 'education_num', 'capital_gain', 'capital_lost', 'hours_week'])

# %%
outliers_capital = df[(df['capital_gain'] == 0) | (df['capital_lost'] == 0)]

# %%
outliers_capital
# Out:
#             state-gov  final_weight    bachelors  education_num  \
# 39
# 50   Self-emp-not-inc         83311    Bachelors             13
# 38            Private        215646      HS-grad              9
# 53            Private        234721         11th              7
# 28            Private        338409    Bachelors             13
# 37            Private        284582      Masters             14
# ..                ...           ...          ...            ...
# 27            Private        257302   Assoc-acdm             12
# 40            Private        154374      HS-grad              9
# 58            Private        151910      HS-grad              9
# 22            Private        201490      HS-grad              9
# 52       Self-emp-inc        287927      HS-grad              9
#
#          marital_status           ocupation    relationship ethnicity  \
# 39
# 50   Married-civ-spouse     Exec-managerial         Husband     White
# 38             Divorced   Handlers-cleaners   Not-in-family     White
# 53   Married-civ-spouse   Handlers-cleaners         Husband     Black
# 28   Married-civ-spouse      Prof-specialty            Wife     Black
# 37   Married-civ-spouse     Exec-managerial            Wife     White
# ..                  ...                 ...             ...       ...
# 27   Married-civ-spouse        Tech-support            Wife     White
# 40   Married-civ-spouse   Machine-op-inspct         Husband     White
# 58              Widowed        Adm-clerical       Unmarried     White
# 22        Never-married        Adm-clerical       Own-child     White
# 52   Married-civ-spouse     Exec-managerial            Wife     White
#
#      gender  capital_gain  capital_lost  hours_week         country  salary
# 39
# 50     Male             0             0          13   United-States   <=50K
# 38     Male             0             0          40   United-States   <=50K
# 53     Male             0             0          40   United-States   <=50K
# 28   Female             0             0          40            Cuba   <=50K
# 37   Female             0             0          40   United-States   <=50K
# ..      ...           ...           ...         ...             ...     ...
# 27   Female             0             0          38   United-States   <=50K
# 40     Male             0             0          40   United-States    >50K
# 58   Female             0             0          40   United-States   <=50K
# 22     Male             0             0          20   United-States   <=50K
# 52   Female         15024             0          40   United-States    >50K
#
# [32560 rows x 14 columns]

# %% [markdown]
# Comprobamos el máximo y el mínimo para filtrar el DataFrame:

# %%
df["final_weight"].min()
# Out:
# 12285

# %%
df["final_weight"].max()
# Out:
# 1484705

# %%
df["census"] = pd.cut(df["final_weight"], bins = 2, labels = ["Bajo", "Alto"])

# %%
df["census"].unique()
# Out:
# ['Bajo', 'Alto']
# Categories (2, object): ['Bajo' < 'Alto']

# %%
df.sample()
# Out:
#    state-gov  final_weight   bachelors  education_num  marital_status  \
# 39
# 28   Private        338376   Bachelors             13   Never-married
#
#           ocupation relationship ethnicity gender  capital_gain  capital_lost  \
# 39
# 28   Prof-specialty    Own-child     White   Male             0             0
#
#     hours_week         country  salary census
# 39
# 28          40   United-States   <=50K   Bajo

# %%
df2 = pd.DataFrame(df["census"] == "Alto")
df3 = pd.DataFramedf["census"] == "Bajo"

# %%
df2.head()
# Out:
#     census
# 39
# 50   False
# 38   False
# 53   False
# 28   False
# 37   False

# %% [markdown]
# Variable predictora: bachelor, ethincity o todas
# variable respuesta : <=50k

# %% [markdown]
# Sustituir outliers education por mediana (son pocos):

# %%
df.columns
# Out:
# Index(['state-gov', 'final_weight', 'bachelors', 'education_num',
#        'marital_status', 'ocupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_lost', 'hours_week', 'country', 'salary',
#        'census'],
#       dtype='object')

# %% [markdown]
# revisar de aqui abajo
#
# Mari: Hago el drop pero no soy capaz de guardarlo, me da NoneType y aunque haga pd.DataFrame sale vacío :(
#
# Así que lo guardo en una variable sin más.

# %%
df_final_weight = df["final_weight"]

# %%
df.drop(columns = ["capital_gain", "capital_lost"], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['state-gov', 'final_weight', 'bachelors', 'education_num',
#        'marital_status', 'ocupation', 'relationship', 'ethnicity', 'gender',
#        'hours_week', 'country', 'salary', 'census'],
#       dtype='object')

# %%
df.head()
# Out:
#             state-gov  final_weight   bachelors  education_num  \
# 39
# 50   Self-emp-not-inc         83311   Bachelors             13
# 38            Private        215646     HS-grad              9
# 53            Private        234721        11th              7
# 28            Private        338409   Bachelors             13
# 37            Private        284582     Masters             14
#
#          marital_status           ocupation    relationship ethnicity  \
# 39
# 50   Married-civ-spouse     Exec-managerial         Husband     White
# 38             Divorced   Handlers-cleaners   Not-in-family     White
# 53   Married-civ-spouse   Handlers-cleaners         Husband     Black
# 28   Married-civ-spouse      Prof-specialty            Wife     Black
# 37   Married-civ-spouse     Exec-managerial            Wife     White
#
#      gender  hours_week         country  salary census
# 39
# 50     Male          13   United-States   <=50K   Bajo
# 38     Male          40   United-States   <=50K   Bajo
# 53     Male          40   United-States   <=50K   Bajo
# 28   Female          40            Cuba   <=50K   Bajo
# 37   Female          40   United-States   <=50K   Bajo

# %%
df.to_csv("data/adult.data_limpio.csv")
