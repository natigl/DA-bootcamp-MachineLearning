# %% [markdown]
# ### Pair Programming - Encoding

# %% [markdown]
# - Hacer una códificación de la/las variables categóricas que tengáis en vuestro set de datos.
# - Recordad que lo primero que deberéis hacer es decidir su vuestras variables tienen o no orden, para que en función de esto uséis una aproximación u otra.
# - Guardad el dataframe, donde deberíais tener las variables estadandarizas, normalizadas y codificadas en un csv para usarlo en el próximo pairprogramming

# %%
import pandas as pd
import sklearn 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data/adult.numericas_robust.csv", index_col = 0)

# %% [markdown]
# ***
# ### Map

# %%
mapa_gender = {' Female': 1, ' Male': 0}
mapa_census = {'Bajo' : 0, 'Alto' : 1}

# %%
df["gender_map"] = df["gender"].map(mapa_gender)

# %%
df["census_map"] = df["census"].map(mapa_census)

# %%
df.head(2)
# Out:
#            work_class  final_weight   education  education_yrs  \
# 39
# 50   Self-emp-not-inc      0.407581   Bachelors      -0.333333
# 38            Private      0.730681     HS-grad       0.666667
#
#          marital_status          occupation    relationship ethnicity gender  \
# 39
# 50   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 38             Divorced   Handlers-cleaners   Not-in-family     White   Male
#
#     capital_gain  capital_lost  hours_week         country  salary census  \
# 39
# 50           0.0           0.0        -2.0   United-States   32755   Bajo
# 38           0.0           0.0         0.0   United-States   45156   Bajo
#
#     salary_log  gender_map  census_map
# 39
# 50   10.396811           0           0
# 38   10.717878           0           0

# %% [markdown]
# ***
# ### Ordinal Encoder

# %% [markdown]
# - Education

# %%
orden_education = [" Preschool", ' 1st-4th', ' 5th-6th', ' 7th-8th', ' 9th', ' 10th', ' 11th', ' 12th', ' HS-grad', ' Assoc-acdm', ' Assoc-voc', ' Some-college', ' Prof-school', ' Bachelors', ' Masters', ' Doctorate', ]

# %%
df_sin_orden = pd.DataFrame(df["education"])

# %%
df_sin_orden.head()
# Out:
#      education
# 39
# 50   Bachelors
# 38     HS-grad
# 53        11th
# 28   Bachelors
# 37     Masters

# %%
def ordinal_encoder(df, columna, orden_valores):
    
    ordinal = OrdinalEncoder(categories = [orden_education], dtype = int)

    transformados_oe = ordinal.fit_transform(df[[columna]])
    
    oe_df = pd.DataFrame(transformados_oe)

    df[columna] = oe_df
     
    return df

# %%
df_education_oe = ordinal_encoder(df_sin_orden, "education", orden_education)

# %%
df_education_oe.head()
# Out:
#     education
# 39
# 50          8
# 38          9
# 53          8
# 28          8
# 37         11

# %%
final = pd.concat([df, df_education_oe],axis=1)

# %% [markdown]
# ***
# - Hacer el encoding de **work class**, **marital_status**, **ethnicity** y **country** (sin orden).

# %%
dummies_marital = pd.get_dummies(df['marital_status'], prefix_sep = "_", prefix = 'marital_status', dtype = int)
dummies_marital.head(2)
# Out:
#     marital_status_ Divorced  marital_status_ Married-AF-spouse  \
# 39
# 50                         0                                  0
# 38                         1                                  0
#
#     marital_status_ Married-civ-spouse  marital_status_ Married-spouse-absent  \
# 39
# 50                                   1                                      0
# 38                                   0                                      0
#
#     marital_status_ Never-married  marital_status_ Separated  \
# 39
# 50                              0                          0
# 38                              0                          0
#
#     marital_status_ Widowed
# 39
# 50                        0
# 38                        0

# %%
dummies_country = pd.get_dummies(df['country'], prefix_sep = "_", prefix = 'country', dtype = int)
dummies_country.head(2)
# Out:
#     country_ ?  country_ Cambodia  country_ Canada  country_ China  \
# 39
# 50           0                  0                0               0
# 38           0                  0                0               0
#
#     country_ Columbia  country_ Cuba  country_ Dominican-Republic  \
# 39
# 50                  0              0                            0
# 38                  0              0                            0
#
#     country_ Ecuador  country_ El-Salvador  country_ England  ...  \
# 39                                                            ...
# 50                 0                     0                 0  ...
# 38                 0                     0                 0  ...
#
#     country_ Portugal  country_ Puerto-Rico  country_ Scotland  \
# 39
# 50                  0                     0                  0
# 38                  0                     0                  0
#
#     country_ South  country_ Taiwan  country_ Thailand  \
# 39
# 50               0                0                  0
# 38               0                0                  0
#
#     country_ Trinadad&Tobago  country_ United-States  country_ Vietnam  \
# 39
# 50                         0                       1                 0
# 38                         0                       1                 0
#
#     country_ Yugoslavia
# 39
# 50                    0
# 38                    0
#
# [2 rows x 42 columns]

# %% [markdown]
# - Ethnicity

# %%
dummies_ethnicity = pd.get_dummies(df["ethnicity"], prefix_sep = "_", prefix = "ethnicity", dtype = int)
dummies_ethnicity.head(2)
# Out:
#     ethnicity_ Amer-Indian-Eskimo  ethnicity_ Asian-Pac-Islander  \
# 39
# 50                              0                              0
# 38                              0                              0
#
#     ethnicity_ Black  ethnicity_ Other  ethnicity_ White
# 39
# 50                 0                 0                 1
# 38                 0                 0                 1

# %%
dummies_work_class = pd.get_dummies(df['work_class'], prefix_sep = "_", prefix = 'work_class', dtype = int)
dummies_work_class.head(2)
# Out:
#     work_class_ ?  work_class_ Federal-gov  work_class_ Local-gov  \
# 39
# 50              0                        0                      0
# 38              0                        0                      0
#
#     work_class_ Never-worked  work_class_ Private  work_class_ Self-emp-inc  \
# 39
# 50                         0                    0                         0
# 38                         0                    1                         0
#
#     work_class_ Self-emp-not-inc  work_class_ State-gov  \
# 39
# 50                             1                      0
# 38                             0                      0
#
#     work_class_ Without-pay
# 39
# 50                        0
# 38                        0

# %%
dummies_occupation= pd.get_dummies(df['occupation'], prefix_sep = "_", prefix = 'occupation', dtype = int)
dummies_occupation.head(2)
# Out:
#     occupation_ ?  occupation_ Adm-clerical  occupation_ Armed-Forces  \
# 39
# 50              0                         0                         0
# 38              0                         0                         0
#
#     occupation_ Craft-repair  occupation_ Exec-managerial  \
# 39
# 50                         0                            1
# 38                         0                            0
#
#     occupation_ Farming-fishing  occupation_ Handlers-cleaners  \
# 39
# 50                            0                              0
# 38                            0                              1
#
#     occupation_ Machine-op-inspct  occupation_ Other-service  \
# 39
# 50                              0                          0
# 38                              0                          0
#
#     occupation_ Priv-house-serv  occupation_ Prof-specialty  \
# 39
# 50                            0                           0
# 38                            0                           0
#
#     occupation_ Protective-serv  occupation_ Sales  occupation_ Tech-support  \
# 39
# 50                            0                  0                         0
# 38                            0                  0                         0
#
#     occupation_ Transport-moving
# 39
# 50                             0
# 38                             0

# %%
dummies_relationship = pd.get_dummies(df['relationship'], prefix_sep = "_", prefix = 'relationship', dtype = int)
dummies_relationship.head(2)
# Out:
#     relationship_ Husband  relationship_ Not-in-family  \
# 39
# 50                      1                            0
# 38                      0                            1
#
#     relationship_ Other-relative  relationship_ Own-child  \
# 39
# 50                             0                        0
# 38                             0                        0
#
#     relationship_ Unmarried  relationship_ Wife
# 39
# 50                        0                   0
# 38                        0                   0

# %%
df_encoding = pd.concat([df,dummies_relationship,dummies_occupation, dummies_work_class, dummies_ethnicity, dummies_marital, dummies_country,df_education_oe], axis = 1)
df_encoding.head(2)
# Out:
#            work_class  final_weight   education  education_yrs  \
# 39
# 50   Self-emp-not-inc      0.407581   Bachelors      -0.333333
# 38            Private      0.730681     HS-grad       0.666667
#
#          marital_status          occupation    relationship ethnicity gender  \
# 39
# 50   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 38             Divorced   Handlers-cleaners   Not-in-family     White   Male
#
#     capital_gain  ...  country_ Puerto-Rico  country_ Scotland country_ South  \
# 39                ...
# 50           0.0  ...                     0                  0              0
# 38           0.0  ...                     0                  0              0
#
#     country_ Taiwan country_ Thailand  country_ Trinadad&Tobago  \
# 39
# 50                0                 0                         0
# 38                0                 0                         0
#
#     country_ United-States  country_ Vietnam  country_ Yugoslavia  education
# 39
# 50                       1                 0                    0          8
# 38                       1                 0                    0          9
#
# [2 rows x 103 columns]

# %%
df_encoding.drop(["occupation", "relationship", "marital_status", "country", "ethnicity", "work_class", "education", "gender", "census"], axis = 1, inplace = True)

# %%
df_encoding
# Out:
#     final_weight  education_yrs  capital_gain  capital_lost  hours_week  \
# 39
# 50      0.407581      -0.333333           0.0           0.0        -2.0
# 38      0.730681       0.666667           0.0           0.0         0.0
# 53     -0.574814      -0.333333           0.0           0.0         4.0
# 28      0.125840      -0.333333           0.0           0.0         0.0
# 37     -0.790191       0.000000           0.0           0.0        -0.4
# ..           ...            ...           ...           ...         ...
# 27      1.584401      -0.333333           0.0           0.0         8.0
# 40     -0.753688       1.000000           0.0           0.0         0.0
# 58      0.082056      -0.333333        5013.0           0.0         0.0
# 22     -0.514381      -1.000000           0.0        2042.0         0.0
# 52      0.614160       1.000000           0.0           0.0         3.0
#
#     salary  salary_log  gender_map  census_map  relationship_ Husband  ...  \
# 39                                                                     ...
# 50   32755   10.396811           0           0                      1  ...
# 38   45156   10.717878           0           0                      0  ...
# 53   39938   10.595084           0           0                      1  ...
# 28   26464   10.183541           1           0                      0  ...
# 37   36976   10.518024           1           0                      0  ...
# ..     ...         ...         ...         ...                    ...  ...
# 27   42582   10.659187           1           0                      0  ...
# 40   62257   11.039026           0           0                      1  ...
# 58   35340   10.472771           1           0                      0  ...
# 22   34013   10.434498           0           0                      0  ...
# 52   61969   11.034390           1           0                      0  ...
#
#     country_ Portugal  country_ Puerto-Rico  country_ Scotland  \
# 39
# 50                  0                     0                  0
# 38                  0                     0                  0
# 53                  0                     0                  0
# 28                  0                     0                  0
# 37                  0                     0                  0
# ..                ...                   ...                ...
# 27                  0                     0                  0
# 40                  0                     0                  0
# 58                  0                     0                  0
# 22                  0                     0                  0
# 52                  0                     0                  0
#
#     country_ South  country_ Taiwan  country_ Thailand  \
# 39
# 50               0                0                  0
# 38               0                0                  0
# 53               0                0                  0
# 28               0                0                  0
# 37               0                0                  0
# ..             ...              ...                ...
# 27               0                0                  0
# 40               0                0                  0
# 58               0                0                  0
# 22               0                0                  0
# 52               0                0                  0
#
#     country_ Trinadad&Tobago  country_ United-States  country_ Vietnam  \
# 39
# 50                         0                       1                 0
# 38                         0                       1                 0
# 53                         0                       1                 0
# 28                         0                       0                 0
# 37                         0                       1                 0
# ..                       ...                     ...               ...
# 27                         0                       1                 0
# 40                         0                       1                 0
# 58                         0                       1                 0
# 22                         0                       1                 0
# 52                         0                       1                 0
#
#     country_ Yugoslavia
# 39
# 50                    0
# 38                    0
# 53                    0
# 28                    0
# 37                    0
# ..                  ...
# 27                    0
# 40                    0
# 58                    0
# 22                    0
# 52                    0
#
# [32560 rows x 93 columns]

# %%
df_encoding.to_csv("data/adults_encoding.csv")
